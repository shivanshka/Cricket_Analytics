# %% [markdown]
# # Data Scrapping

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
from tqdm import tqdm

# %% [markdown]
# ### Scrapping fixtures and winners data

# %%
URL = r"https://stats.espncricinfo.com/ci/engine/records/team/match_results.html?id=14450;type=tournament"

# %%
page = requests.get(URL)
page
# Out:
# <Response [200]>

# %%
page_content = page.content

# %%
soup = bs(page_content,"html.parser")

# %%
table_data = soup.findAll("tr",{"class":"data1"})

# %%
team1=[]
team2=[]
winner=[]
margin=[]
ground=[]
match_date=[]
match_id=[]
score_card_url=[]

# %%
for i in table_data:
    data = i.text.split("\n")
    team1.append(data[1])
    team2.append(data[2])
    winner.append(data[3])
    margin.append(data[4])
    ground.append(data[5])
    match_date.append(data[6])
    match_id.append(data[7])
    score_card_url.append(i.findAll("td")[-1].a.get("href"))

# %%
table_data[0].findAll("td")[-1].a.get("href")
# Out:
# '/ci/engine/match/1298135.html'

# %%
data_dict = {
    "Match_Date" : match_date,
    "Match_Id" : match_id,
    "Team_1" : team1,
    "Team_2" : team2,
    "Winner" : winner,
    "Margin" : margin,
    "Ground" : ground
}



t20_df = pd.DataFrame(data_dict)

# %%
t20_df
# Out:
#       Match_Date      Match_Id        Team_1        Team_2        Winner  \
# 0   Oct 16, 2022   T20I # 1823       Namibia     Sri Lanka       Namibia
# 1   Oct 16, 2022   T20I # 1825   Netherlands        U.A.E.   Netherlands
# 2   Oct 17, 2022   T20I # 1826      Scotland   West Indies      Scotland
# 3   Oct 17, 2022   T20I # 1828       Ireland      Zimbabwe      Zimbabwe
# 4   Oct 18, 2022   T20I # 1830       Namibia   Netherlands   Netherlands
# 5   Oct 18, 2022   T20I # 1832     Sri Lanka        U.A.E.     Sri Lanka
# 6   Oct 19, 2022   T20I # 1833       Ireland      Scotland       Ireland
# 7   Oct 19, 2022   T20I # 1834   West Indies      Zimbabwe   West Indies
# 8   Oct 20, 2022   T20I # 1835   Netherlands     Sri Lanka     Sri Lanka
# 9   Oct 20, 2022   T20I # 1836       Namibia        U.A.E.        U.A.E.
# 10  Oct 21, 2022   T20I # 1837       Ireland   West Indies       Ireland
# 11  Oct 21, 2022   T20I # 1838      Scotland      Zimbabwe      Zimbabwe
# 12  Oct 22, 2022   T20I # 1839     Australia   New Zealand   New Zealand
# 13  Oct 22, 2022   T20I # 1840   Afghanistan       England       England
# 14  Oct 23, 2022   T20I # 1841       Ireland     Sri Lanka     Sri Lanka
# 15  Oct 23, 2022   T20I # 1842         India      Pakistan         India
# 16  Oct 24, 2022   T20I # 1843    Bangladesh   Netherlands    Bangladesh
# 17  Oct 24, 2022   T20I # 1844  South Africa      Zimbabwe     no result
# 18  Oct 25, 2022   T20I # 1845     Australia     Sri Lanka     Australia
# 19  Oct 26, 2022   T20I # 1846       England       Ireland       Ireland
# 20  Oct 26, 2022  T20I # 1846a   Afghanistan   New Zealand     abandoned
# 21  Oct 27, 2022   T20I # 1847    Bangladesh  South Africa  South Africa
# 22  Oct 27, 2022   T20I # 1848         India   Netherlands         India
# 23  Oct 27, 2022   T20I # 1849      Pakistan      Zimbabwe      Zimbabwe
# 24  Oct 28, 2022  T20I # 1849a   Afghanistan       Ireland     abandoned
# 25  Oct 28, 2022  T20I # 1849b     Australia       England     abandoned
# 26  Oct 29, 2022   T20I # 1850   New Zealand     Sri Lanka   New Zealand
# 27  Oct 30, 2022   T20I # 1851    Bangladesh      Zimbabwe    Bangladesh
# 28  Oct 30, 2022   T20I # 1852   Netherlands      Pakistan      Pakistan
# 29  Oct 30, 2022   T20I # 1853         India  South Africa  South Africa
# 30  Oct 31, 2022   T20I # 1855     Australia       Ireland     Australia
# 31   Nov 1, 2022   T20I # 1856   Afghanistan     Sri Lanka     Sri Lanka
# 32   Nov 1, 2022   T20I # 1858       England   New Zealand       England
# 33   Nov 2, 2022   T20I # 1859   Netherlands      Zimbabwe   Netherlands
# 34   Nov 2, 2022   T20I # 1860    Bangladesh         India         India
# 35   Nov 3, 2022   T20I # 1861      Pakistan  South Africa      Pakistan
# 36   Nov 4, 2022   T20I # 1862       Ireland   New Zealand   New Zealand
# 37   Nov 4, 2022   T20I # 1864     Australia   Afghanistan     Australia
# 38   Nov 5, 2022   T20I # 1867       England     Sri Lanka       England
# 39   Nov 6, 2022   T20I # 1871   Netherlands  South Africa   Netherlands
# 40   Nov 6, 2022   T20I # 1872    Bangladesh      Pakistan      Pakistan
# 41   Nov 6, 2022   T20I # 1873         India      Zimbabwe         India
# 42   Nov 9, 2022   T20I # 1877   New Zealand      Pakistan      Pakistan
# 43  Nov 10, 2022   T20I # 1878       England         India       England
# 44  Nov 13, 2022   T20I # 1879       England      Pakistan       England
#
#         Margin     Ground
# 0      55 runs    Geelong
# 1    3 wickets    Geelong
# 2      42 runs     Hobart
# 3      31 runs     Hobart
# 4    5 wickets    Geelong
# 5      79 runs    Geelong
# 6    6 wickets     Hobart
# 7      31 runs     Hobart
# 8      16 runs    Geelong
# 9       7 runs    Geelong
# 10   9 wickets     Hobart
# 11   5 wickets     Hobart
# 12     89 runs     Sydney
# 13   5 wickets      Perth
# 14   9 wickets     Hobart
# 15   4 wickets  Melbourne
# 16      9 runs     Hobart
# 17                 Hobart
# 18   7 wickets      Perth
# 19      5 runs  Melbourne
# 20              Melbourne
# 21    104 runs     Sydney
# 22     56 runs     Sydney
# 23       1 run      Perth
# 24              Melbourne
# 25              Melbourne
# 26     65 runs     Sydney
# 27      3 runs   Brisbane
# 28   6 wickets      Perth
# 29   5 wickets      Perth
# 30     42 runs   Brisbane
# 31   6 wickets   Brisbane
# 32     20 runs   Brisbane
# 33   5 wickets   Adelaide
# 34      5 runs   Adelaide
# 35     33 runs     Sydney
# 36     35 runs   Adelaide
# 37      4 runs   Adelaide
# 38   4 wickets     Sydney
# 39     13 runs   Adelaide
# 40   5 wickets   Adelaide
# 41     71 runs  Melbourne
# 42   7 wickets     Sydney
# 43  10 wickets   Adelaide
# 44   5 wickets  Melbourne

# %%
t20_df.to_csv("t20_df.csv", index = False)

# %%
df = pd.read_html(URL)

# %%
df[0]
# Out:
#           Team 1        Team 2        Winner      Margin     Ground  \
# 0        Namibia     Sri Lanka       Namibia     55 runs    Geelong
# 1    Netherlands        U.A.E.   Netherlands   3 wickets    Geelong
# 2       Scotland   West Indies      Scotland     42 runs     Hobart
# 3        Ireland      Zimbabwe      Zimbabwe     31 runs     Hobart
# 4        Namibia   Netherlands   Netherlands   5 wickets    Geelong
# 5      Sri Lanka        U.A.E.     Sri Lanka     79 runs    Geelong
# 6        Ireland      Scotland       Ireland   6 wickets     Hobart
# 7    West Indies      Zimbabwe   West Indies     31 runs     Hobart
# 8    Netherlands     Sri Lanka     Sri Lanka     16 runs    Geelong
# 9        Namibia        U.A.E.        U.A.E.      7 runs    Geelong
# 10       Ireland   West Indies       Ireland   9 wickets     Hobart
# 11      Scotland      Zimbabwe      Zimbabwe   5 wickets     Hobart
# 12     Australia   New Zealand   New Zealand     89 runs     Sydney
# 13   Afghanistan       England       England   5 wickets      Perth
# 14       Ireland     Sri Lanka     Sri Lanka   9 wickets     Hobart
# 15         India      Pakistan         India   4 wickets  Melbourne
# 16    Bangladesh   Netherlands    Bangladesh      9 runs     Hobart
# 17  South Africa      Zimbabwe     no result         NaN     Hobart
# 18     Australia     Sri Lanka     Australia   7 wickets      Perth
# 19       England       Ireland       Ireland      5 runs  Melbourne
# 20   Afghanistan   New Zealand     abandoned         NaN  Melbourne
# 21    Bangladesh  South Africa  South Africa    104 runs     Sydney
# 22         India   Netherlands         India     56 runs     Sydney
# 23      Pakistan      Zimbabwe      Zimbabwe       1 run      Perth
# 24   Afghanistan       Ireland     abandoned         NaN  Melbourne
# 25     Australia       England     abandoned         NaN  Melbourne
# 26   New Zealand     Sri Lanka   New Zealand     65 runs     Sydney
# 27    Bangladesh      Zimbabwe    Bangladesh      3 runs   Brisbane
# 28   Netherlands      Pakistan      Pakistan   6 wickets      Perth
# 29         India  South Africa  South Africa   5 wickets      Perth
# 30     Australia       Ireland     Australia     42 runs   Brisbane
# 31   Afghanistan     Sri Lanka     Sri Lanka   6 wickets   Brisbane
# 32       England   New Zealand       England     20 runs   Brisbane
# 33   Netherlands      Zimbabwe   Netherlands   5 wickets   Adelaide
# 34    Bangladesh         India         India      5 runs   Adelaide
# 35      Pakistan  South Africa      Pakistan     33 runs     Sydney
# 36       Ireland   New Zealand   New Zealand     35 runs   Adelaide
# 37     Australia   Afghanistan     Australia      4 runs   Adelaide
# 38       England     Sri Lanka       England   4 wickets     Sydney
# 39   Netherlands  South Africa   Netherlands     13 runs   Adelaide
# 40    Bangladesh      Pakistan      Pakistan   5 wickets   Adelaide
# 41         India      Zimbabwe         India     71 runs  Melbourne
# 42   New Zealand      Pakistan      Pakistan   7 wickets     Sydney
# 43       England         India       England  10 wickets   Adelaide
# 44       England      Pakistan       England   5 wickets  Melbourne
#
#       Match Date     Scorecard
# 0   Oct 16, 2022   T20I # 1823
# 1   Oct 16, 2022   T20I # 1825
# 2   Oct 17, 2022   T20I # 1826
# 3   Oct 17, 2022   T20I # 1828
# 4   Oct 18, 2022   T20I # 1830
# 5   Oct 18, 2022   T20I # 1832
# 6   Oct 19, 2022   T20I # 1833
# 7   Oct 19, 2022   T20I # 1834
# 8   Oct 20, 2022   T20I # 1835
# 9   Oct 20, 2022   T20I # 1836
# 10  Oct 21, 2022   T20I # 1837
# 11  Oct 21, 2022   T20I # 1838
# 12  Oct 22, 2022   T20I # 1839
# 13  Oct 22, 2022   T20I # 1840
# 14  Oct 23, 2022   T20I # 1841
# 15  Oct 23, 2022   T20I # 1842
# 16  Oct 24, 2022   T20I # 1843
# 17  Oct 24, 2022   T20I # 1844
# 18  Oct 25, 2022   T20I # 1845
# 19  Oct 26, 2022   T20I # 1846
# 20  Oct 26, 2022  T20I # 1846a
# 21  Oct 27, 2022   T20I # 1847
# 22  Oct 27, 2022   T20I # 1848
# 23  Oct 27, 2022   T20I # 1849
# 24  Oct 28, 2022  T20I # 1849a
# 25  Oct 28, 2022  T20I # 1849b
# 26  Oct 29, 2022   T20I # 1850
# 27  Oct 30, 2022   T20I # 1851
# 28  Oct 30, 2022   T20I # 1852
# 29  Oct 30, 2022   T20I # 1853
# 30  Oct 31, 2022   T20I # 1855
# 31   Nov 1, 2022   T20I # 1856
# 32   Nov 1, 2022   T20I # 1858
# 33   Nov 2, 2022   T20I # 1859
# 34   Nov 2, 2022   T20I # 1860
# 35   Nov 3, 2022   T20I # 1861
# 36   Nov 4, 2022   T20I # 1862
# 37   Nov 4, 2022   T20I # 1864
# 38   Nov 5, 2022   T20I # 1867
# 39   Nov 6, 2022   T20I # 1871
# 40   Nov 6, 2022   T20I # 1872
# 41   Nov 6, 2022   T20I # 1873
# 42   Nov 9, 2022   T20I # 1877
# 43  Nov 10, 2022   T20I # 1878
# 44  Nov 13, 2022   T20I # 1879

# %% [markdown]
# ### Scorecard Scrapping for each match

# %%
prefix = "https://stats.espncricinfo.com"
score_card_url[0]
# Out:
# '/ci/engine/match/1298135.html'

# %%
scorecard_url = prefix+score_card_url[1]

# %%
sd_df = pd.read_html(scorecard_url)

# %%
score_page = requests.get(scorecard_url).content
soup2 = bs(score_page, "html.parser")

# %% [markdown]
# #### Batting scorecard scrapper

# %%
#d = soup2.findAll("div",{"class":"ds-w-full ds-bg-fill-content-prime ds-overflow-hidden ds-rounded-xl ds-border ds-border-line ds-mb-4"}
def get_match_scores(div_tag): 
    match=[]
    team=[]
    bat_name=[]
    bat_pos=[]
    dismissal=[]
    runs=[]
    balls =[]
    fours =[]
    sixes=[]
    strike_rate=[]

    for current_team in [0,1]:
        pos=0
        for idx, batter in enumerate(div_tag[current_team].findAll("tr")):
            if idx!=0:   
                details = batter.findAll("td")
                if details[0].text =='':
                    continue
                elif details[0].text == 'Extras':
                    break
                else:
                    pos=pos+1
                    team.append(div_tag[current_team].div.div.span.span.text)
                    bat_pos.append(pos)
                    bat_name.append(details[0].text)
                    dismissal.append(details[1].text)
                    runs.append(details[2].text)
                    balls.append(details[3].text)
                    fours.append(details[5].text)
                    sixes.append(details[6].text)
                    strike_rate.append(details[7].text)
                    
    df = pd.DataFrame({
        "Team_Innings":team,
        "Batting_Pos":bat_pos,
        "Batsman":bat_name,
        "Dismissal":dismissal,
        "Runs":runs,
        "Balls":balls,
        "4s":fours,
        "6s":sixes,
        "SR":strike_rate
    })
    df["Match"] = f"{df.Team_Innings.unique()[0]} vs {df.Team_Innings.unique()[1]}"
    df = df.loc[:,["Match","Team_Innings","Batting_Pos","Batsman","Dismissal","Runs","Balls","4s","6s","SR"]]
    return df

# %%
def get_bowl_stats(url, div_tag):
    team1 = div_tag[1].div.div.span.span.text
    team2 = div_tag[0].div.div.span.span.text
    
    stats = pd.read_html(url)
    idx_list1=[row[0] for row in enumerate(stats[1].iterrows()) if len(row[1][1][0])>30]
    card_1 = stats[1].drop(index=idx_list1)
    card_1["Bowling_Team"] = team1
    
    idx_list2=[row[0] for row in enumerate(stats[3].iterrows()) if len(row[1][1][0])>30]
    card_2 = stats[3].drop(index=idx_list2)
    card_2["Bowling_Team"] =team2
    
    data = pd.concat([card_1,card_2],axis=0, ignore_index=True)
    data["Match"] = f"{team2} vs {team1}"
    
    return data

# %%
bat_fact_df = pd.DataFrame()
bowl_fact_df = pd.DataFrame()
prefix = "https://stats.espncricinfo.com"

print(f"{'>'*10} Collecting All Scorecards for T20 Men's Cricket Worldcup {'<'*10}")
print("-"*30)
for url in tqdm(score_card_url):
    try: 
        scorecard_url = prefix+url
        score_page = requests.get(scorecard_url).content
        soup2 = bs(score_page, "html.parser")

        div_tag = soup2.findAll("div",{"class":"ds-w-full ds-bg-fill-content-prime ds-overflow-hidden ds-rounded-xl ds-border ds-border-line ds-mb-4"})

        df = get_match_scores(div_tag)
        bat_fact_df = pd.concat([bat_fact_df,df],axis=0,ignore_index=True)
        
        bowl_df = get_bowl_stats(scorecard_url, div_tag)
        bowl_fact_df = pd.concat([bowl_fact_df,bowl_df],axis=0,ignore_index=True)
        bowl_fact_df = bowl_fact_df.rename(columns={"BOWLING":"bowler","O":"overs","M":"maidens","R":"runs","W":"wickets","ECON":"economy"})
        bowl_fact_df = bowl_fact_df.loc[:,["Match","Bowling_Team","bowler","overs", "maidens","runs","wickets","economy","0s","4s","6s","WD","NB"]]
    except Exception as e:
        continue
print("Scrapping Successfull!!! \n Saved DataFrame!!!")
# Out:
# >>>>>>>>>> Collecting All Scorecards for T20 Men's Cricket Worldcup <<<<<<<<<<
# ------------------------------
# 100%|██████████████████████████████████████████████████████████████████████████████████| 45/45 [02:07<00:00,  2.84s/it]
# Scrapping Successfull!!!
#  Saved DataFrame!!!

# %%
bat_fact_df.to_csv("t20_bat_summary.csv",index=None)
bowl_fact_df.to_csv("t20_bowl_fact_summary.csv",index=None)
